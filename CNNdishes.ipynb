# %% [markdown]
# <a href="https://colab.research.google.com/github/Trrunghau/AI/blob/main/CNNdishes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from os import listdir
from numpy import asarray,save
from keras.utils import load_img, img_to_array

# %%
folder = '/content/drive/MyDrive/monan/dish_train/'

photos, labels = list(), list()
for file in listdir(folder) :
  output = 0.0
  if file.startswith('xeo'):
    output = 1.0
  if file.startswith('phobo'):
    output = 2.0
  if file.startswith('loc'):
    output = 3.0
  if file.startswith('chua'):
    output = 4.0
  if file.startswith('tet'):
    output = 5.0
  if file.startswith('tam'):
    output = 6.0
  if file.startswith('xoi'):
    output = 7.0
  if file.startswith('than'):
    output = 8.0
  if file.startswith('mi'):
    output = 9.0
  if file.startswith('nem'):
    output = 10.0
  photo = load_img(folder + file, target_size = (100,100))
  photo = img_to_array(photo)
  photos.append(photo)
  labels.append(output)
photos_train = asarray(photos)
labels_train = asarray(labels)
print(photos_train.shape, labels_train.shape)
save('/content/drive/MyDrive/Colab Notebooks/photos3.npy',photos_train)
save('/content/drive/MyDrive/Colab Notebooks/labels3.npy',labels_train)

class_name = {1: 'bánh xèo',2: 'phở bò',3: 'bột lọc',
                  4: 'canh chua',5: 'bánh tét',6: 'cơm tấm',7: 'xôi',8:'bún thang',9:'bánh mì',10:'nem rán'}
# Out:
# (500, 100, 100, 3) (500,)

# %%
folder = '/content/drive/MyDrive/monan/dish_test/'

photos, labels = list(), list()
for file in listdir(folder) :
  output = 0.0
  if file.startswith('xeo'):
    output = 1.0
  if file.startswith('phobo'):
    output = 2.0
  if file.startswith('loc'):
    output = 3.0
  if file.startswith('chua'):
    output = 4.0
  if file.startswith('tet'):
    output = 5.0
  if file.startswith('tam'):
    output = 6.0
  if file.startswith('xoi'):
    output = 7.0
  if file.startswith('than'):
    output = 8.0
  if file.startswith('mi'):
    output = 9.0
  if file.startswith('nem'):
    output = 10.0
  photo = load_img(folder + file, target_size = (100,100))
  photo = img_to_array(photo)
  photos.append(photo)
  labels.append(output)
photos_test = asarray(photos)
labels_test = asarray(labels)
print(photos_test.shape, labels_test.shape)
save('/content/drive/MyDrive/anhlop_test/photos3.npy',photos_test)
save('/content/drive/MyDrive/anhlop_test/labels3.npy',labels_test)
# Out:
# (100, 100, 100, 3) (100,)

# %%
import matplotlib.pyplot as plt
import numpy as np
img = photos_train[55]
plt.imshow((img*255).astype(np.uint8))
plt.show()

# %%
photos_train = photos_train.reshape(500, 100, 100, 3)
photos_train = photos_train.astype('float32')/255 
photos_test = photos_test.reshape(100, 100, 100, 3)
photos_test = photos_test.astype('float32')/255

from keras.utils import  to_categorical
labels_train = to_categorical(labels_train)
labels_test = to_categorical(labels_test)
photos_train.shape, labels_train.shape, photos_test.shape, labels_test.shape
# Out:
# ((500, 100, 100, 3), (500, 11), (100, 100, 100, 3), (100, 11))

# %%
from keras.models import Sequential, Model
from keras import Input, Model
from keras.optimizers import Adam
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D
from keras.layers import BatchNormalization, LeakyReLU
batch_size = 128
epochs = 40
classes = 11


model = Sequential()
#CNN
model.add(Conv2D(32, kernel_size = (3,3), activation = 'linear',
                 input_shape = (100,100,3), padding = 'same')) 
# nhan tich chap 32 lan
model.add(LeakyReLU(alpha = 0.1))
model.add(MaxPooling2D((2,2), padding = 'same'))

model.add(Conv2D(64, (3,3), activation = 'linear', padding ='same'))
model.add(LeakyReLU(alpha = 0.1))
model.add(MaxPooling2D((2,2), padding = 'same'))

model.add(Conv2D(128, (3,3), activation = 'linear', padding = 'same'))
model.add(LeakyReLU(alpha = 0.1))
model.add(MaxPooling2D((2,2), padding = 'same'))

#ANN
model.add(Flatten())
model.add(Dense(128, activation = 'linear'))
model.add(LeakyReLU(alpha = 0.1))
model.add(Dense(classes, activation ='softmax'))

# %%
#compile
model.compile(optimizer = Adam(), loss = 'categorical_crossentropy', 
              metrics = ['accuracy'])
model.summary()

train = model.fit(photos_train, labels_train, batch_size = batch_size , 
                  epochs = epochs, verbose = 1)

test_loss, test_acc = model.evaluate(photos_test, labels_test)
print('do chinh xac', test_acc)
print('ham mat mat', test_loss)
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_17 (Conv2D)          (None, 100, 100, 32)      896
#
#  leaky_re_lu_22 (LeakyReLU)  (None, 100, 100, 32)      0
#
#  max_pooling2d_17 (MaxPoolin  (None, 50, 50, 32)       0
#  g2D)
#
#  conv2d_18 (Conv2D)          (None, 50, 50, 64)        18496
#
#  leaky_re_lu_23 (LeakyReLU)  (None, 50, 50, 64)        0
#
#  max_pooling2d_18 (MaxPoolin  (None, 25, 25, 64)       0
#  g2D)
#
#  conv2d_19 (Conv2D)          (None, 25, 25, 128)       73856
#
#  leaky_re_lu_24 (LeakyReLU)  (None, 25, 25, 128)       0
#
#  max_pooling2d_19 (MaxPoolin  (None, 13, 13, 128)      0
#  g2D)
#
#  flatten_5 (Flatten)         (None, 21632)             0
#
#  dense_10 (Dense)            (None, 128)               2769024
#
#  leaky_re_lu_25 (LeakyReLU)  (None, 128)               0
#
#  dense_11 (Dense)            (None, 11)                1419
#
# =================================================================
# Total params: 2,863,691
# Trainable params: 2,863,691
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/40
# 4/4 [==============================] - 16s 4s/step - loss: 2.7356 - accuracy: 0.0960
# Epoch 2/40
# 4/4 [==============================] - 14s 4s/step - loss: 2.3647 - accuracy: 0.1260
# Epoch 3/40
# 4/4 [==============================] - 14s 4s/step - loss: 2.2354 - accuracy: 0.1860
# Epoch 4/40
# 4/4 [==============================] - 14s 4s/step - loss: 2.1234 - accuracy: 0.2100
# Epoch 5/40
# 4/4 [==============================] - 14s 4s/step - loss: 1.9838 - accuracy: 0.2720
# Epoch 6/40
# 4/4 [==============================] - 14s 3s/step - loss: 1.8361 - accuracy: 0.3980
# Epoch 7/40
# 4/4 [==============================] - 14s 3s/step - loss: 1.6595 - accuracy: 0.4540
# Epoch 8/40
# 4/4 [==============================] - 14s 3s/step - loss: 1.4920 - accuracy: 0.5180
# Epoch 9/40
# 4/4 [==============================] - 14s 3s/step - loss: 1.3684 - accuracy: 0.5320
# Epoch 10/40
# 4/4 [==============================] - 14s 3s/step - loss: 1.1872 - accuracy: 0.6140
# Epoch 11/40
# 4/4 [==============================] - 14s 3s/step - loss: 1.0105 - accuracy: 0.6500
# Epoch 12/40
# 4/4 [==============================] - 14s 4s/step - loss: 0.9332 - accuracy: 0.6980
# Epoch 13/40
# 4/4 [==============================] - 14s 4s/step - loss: 0.7705 - accuracy: 0.7500
# Epoch 14/40
# 4/4 [==============================] - 14s 4s/step - loss: 0.6163 - accuracy: 0.8120
# Epoch 15/40
# 4/4 [==============================] - 14s 4s/step - loss: 0.4561 - accuracy: 0.8740
# Epoch 16/40
# 4/4 [==============================] - 14s 4s/step - loss: 0.3468 - accuracy: 0.9060
# Epoch 17/40
# 4/4 [==============================] - 14s 4s/step - loss: 0.2306 - accuracy: 0.9580
# Epoch 18/40
# 4/4 [==============================] - 14s 4s/step - loss: 0.1495 - accuracy: 0.9800
# Epoch 19/40
# 4/4 [==============================] - 14s 4s/step - loss: 0.1029 - accuracy: 0.9860
# Epoch 20/40
# 4/4 [==============================] - 14s 4s/step - loss: 0.0668 - accuracy: 0.9880
# Epoch 21/40
# 4/4 [==============================] - 14s 4s/step - loss: 0.0538 - accuracy: 0.9920
# Epoch 22/40
# 4/4 [==============================] - 15s 4s/step - loss: 0.0446 - accuracy: 0.9940
# Epoch 23/40
# 4/4 [==============================] - 14s 4s/step - loss: 0.0380 - accuracy: 0.9940
# Epoch 24/40
# 4/4 [==============================] - 14s 4s/step - loss: 0.0320 - accuracy: 0.9940
# Epoch 25/40
# 4/4 [==============================] - 14s 4s/step - loss: 0.0158 - accuracy: 1.0000
# Epoch 26/40
# 4/4 [==============================] - 14s 3s/step - loss: 0.0090 - accuracy: 1.0000
# Epoch 27/40
# 4/4 [==============================] - 14s 3s/step - loss: 0.0060 - accuracy: 1.0000
# Epoch 28/40
# 4/4 [==============================] - 14s 3s/step - loss: 0.0043 - accuracy: 1.0000
# Epoch 29/40
# 4/4 [==============================] - 14s 3s/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 30/40
# 4/4 [==============================] - 14s 3s/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 31/40
# 4/4 [==============================] - 14s 3s/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 32/40
# 4/4 [==============================] - 14s 3s/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 33/40
# 4/4 [==============================] - 14s 4s/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 34/40
# 4/4 [==============================] - 14s 4s/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 35/40
# 4/4 [==============================] - 14s 4s/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 36/40
# 4/4 [==============================] - 19s 5s/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 37/40
# 4/4 [==============================] - 15s 3s/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 38/40
# 4/4 [==============================] - 14s 3s/step - loss: 9.4160e-04 - accuracy: 1.0000
# Epoch 39/40
# 4/4 [==============================] - 15s 3s/step - loss: 8.8121e-04 - accuracy: 1.0000
# Epoch 40/40
# 4/4 [==============================] - 14s 3s/step - loss: 8.3255e-04 - accuracy: 1.0000
# 4/4 [==============================] - 1s 161ms/step - loss: 4.8821 - accuracy: 0.3100
# do chinh xac 0.3100000023841858
# ham mat mat 4.882122039794922

# %%
accuracy = train.history['accuracy']
loss = train.history['loss']
epochs = range(len(accuracy))
plt.plot(epochs, accuracy, 'k', label = 'Train accuracy')
plt.plot(epochs, loss, 'b', label = 'Train loss')
plt.legend(['Train accuracy', 'Train loss'])
plt.show()

# %%
model.save('/content/drive/MyDrive/Colab Notebooks/modeldishes.h5')

# %%
#test
filePath = '/content/drive/MyDrive/monan/dish_test/mi55.jpg'
testImage = load_img(filePath, color_mode = 'rgb', target_size=(100,100))
arrayImage = img_to_array(testImage).reshape(1,100,100,3)/255
pred = np.argmax(model.predict(arrayImage))
print("Predicted: ", class_name[pred])
plt.imshow(testImage)
# Out:
# 1/1 [==============================] - 0s 31ms/step
# Predicted:  bánh mì

# %%
#test
filePath = '/content/drive/MyDrive/monan/dish_test/tam60.jpg'
testImage = load_img(filePath, color_mode = 'rgb', target_size=(100,100))
arrayImage = img_to_array(testImage).reshape(1,100,100,3)/255
pred = np.argmax(model.predict(arrayImage))
print("Predicted: ", class_name[pred])
plt.imshow(testImage)
# Out:
# 1/1 [==============================] - 0s 48ms/step
# Predicted:  cơm tấm
